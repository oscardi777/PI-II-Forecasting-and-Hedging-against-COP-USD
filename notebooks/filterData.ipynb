# %% [markdown]
# Filtrando fecha inicial del data set:

# %%
import pandas as pd

# %%
pathData = "C:\\Users\\oscar\\Desktop\\University\\PI 2\\PI-II-Forecasting-and-Hedging-against-COP-USD\\data\\raw\\tasa_cop_usd_1993-2025.csv"

df = pd.read_csv(pathData)

df_filtered = df[df['date'] >= '2020-01-01']

df_filtered.to_csv("C:\\Users\\oscar\\Desktop\\University\\PI 2\\PI-II-Forecasting-and-Hedging-against-COP-USD\\data\\raw\\tasa_cop_usd_2020-2025.csv", index=False)
